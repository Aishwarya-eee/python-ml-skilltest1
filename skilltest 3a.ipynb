# %%
Z1 = complex(100, 50)   # Example: 100 + j50 ohms
Z2 = complex(200, -30)  # Example: 200 - j30 ohms


Z_series = Z1 + Z2

Z_parallel = (Z1 * Z2) / (Z1 + Z2)

print("Series Impedance:", Z_series)
print("Parallel Impedance:", Z_parallel)
# Out:
# Series Impedance: (300+20j)
# Parallel Impedance: (72.89823008849558+18.47345132743363j)
