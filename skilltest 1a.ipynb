# %%
# List of exam scores for 20 students
scores = [78, 45, 89, 62, 55, 91, 34, 67, 73, 49, 
          58, 84, 77, 69, 52, 40, 95, 60, 71, 88]

# 1. Overall class performance
average_score = sum(scores) / len(scores)
highest_score = max(scores)
lowest_score = min(scores)

print("Class Performance:")
print("Average Score:", average_score)
print("Highest Score:", highest_score)
print("Lowest Score:", lowest_score)

# 2. Pass/Fail classification
print("\nPass/Fail Classification:")
for i, score in enumerate(scores, start=1):
    if score >= 50:
        print(f"Student {i}: {score} - Pass")
    else:
        print(f"Student {i}: {score} - Fail")

# 3. Letter grade assignment
print("\nLetter Grades:")
for i, score in enumerate(scores, start=1):
    if score >= 85:
        grade = 'A'
    elif score >= 70:
        grade = 'B'
    elif score >= 60:
        grade = 'C'
    elif score >= 50:
        grade = 'D'
    else:
        grade = 'F'
        
    print(f"Student {i}: {score} - Grade {grade}")
# Out:
# Class Performance:
# Average Score: 66.85
# Highest Score: 95
# Lowest Score: 34
#
# Pass/Fail Classification:
# Student 1: 78 - Pass
# Student 2: 45 - Fail
# Student 3: 89 - Pass
# Student 4: 62 - Pass
# Student 5: 55 - Pass
# Student 6: 91 - Pass
# Student 7: 34 - Fail
# Student 8: 67 - Pass
# Student 9: 73 - Pass
# Student 10: 49 - Fail
# Student 11: 58 - Pass
# Student 12: 84 - Pass
# Student 13: 77 - Pass
# Student 14: 69 - Pass
# Student 15: 52 - Pass
# Student 16: 40 - Fail
# Student 17: 95 - Pass
# Student 18: 60 - Pass
# Student 19: 71 - Pass
# Student 20: 88 - Pass
#
# Letter Grades:
# Student 1: 78 - Grade B
# Student 2: 45 - Grade F
# Student 3: 89 - Grade A
# Student 4: 62 - Grade C
# Student 5: 55 - Grade D
# Student 6: 91 - Grade A
# Student 7: 34 - Grade F
# Student 8: 67 - Grade C
# Student 9: 73 - Grade B
# Student 10: 49 - Grade F
# Student 11: 58 - Grade D
# Student 12: 84 - Grade B
# Student 13: 77 - Grade B
# Student 14: 69 - Grade C
# Student 15: 52 - Grade D
# ...
